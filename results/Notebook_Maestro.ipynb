# %% [markdown]
# # Notebook Maestro: Proceso de Filtrado, Modelos y Clustering

# %% [markdown]
# Este notebook ejecuta los scripts generados en orden para llevar a cabo las siguientes etapas:
#
# 1. **Filtrado de datos**.
# 2. **Creación de modelos**.
# 3. **Análisis de clustering**.
# 4. **Integración de notebooks de Ensemble y Comparison**.
#
# Todos los resultados se guardarán en las rutas configuradas en cada script.

# %% [markdown]
# ## 1. Filtrado de Datos

# %%
# Ejecutar el script de filtrado y agrupamiento
# !python Filtering_Grouping.py
# Out:
# Traceback (most recent call last):
#   File "c:\Users\alvar\Documents\Downloads\Filtering_Grouping.py", line 41, in <module>
#     with open(conn_param_file, 'r') as f:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'creds/farm_processdata_conn_config.json'

# %% [markdown]
# ## 2. Creación de Modelos

# %%
# !python MLP_Algorithm_Code_09_12_09_15.py
# Out:
# Figure(1000x800)
# Mejores hiperparámetros: {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (128, 64, 32), 'learning_rate_init': 0.01}
# RMSE Test Redes Neuronales mejoradas: 0.10945790715252061
# RMSE Train Redes Neuronales mejoradas: 0.08380101979533068
# MSE Promedio de la validación cruzada: 0.016020442030655214
# Modelo guardado exitosamente.
# Figure(640x480)
# Figure(640x480)
# Media de variables desescaladas por cluster:
#                    ID  ...  interaccion_eventos_comida
# cluster               ...
# 0        4990.963415  ...                  426.390244
# 1        6044.200000  ...                 8779.000000
# 2        4026.153846  ...                 2235.769231
#
# [3 rows x 17 columns]
# Número de datos por cluster:
#  cluster
# 0    21
# 1     6
# 2     3
# 3     6
# 4     4
# 5    17
# 6    15
# 7     4
# 8     5
# 9    19
# Name: count, dtype: int64
# Iteración 1
# Media de ganancia de peso por sub_cluster:
# sub_cluster
# 0    0.286689
# ...

# %%
# !python MLP_Algorithm_Code_09_16_09_22.py
# Out:
# Figure(1000x800)
# Mejores hiperparámetros: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (128, 64, 32), 'learning_rate_init': 0.001}
# RMSE Test Redes Neuronales mejoradas: 0.09999765521186854
# RMSE Train Redes Neuronales mejoradas: 0.10352176632796675
# MSE Promedio de la validación cruzada: 0.01046087391509631
# Modelo guardado exitosamente.
# Figure(640x480)
# Figure(640x480)
# Media de variables desescaladas por cluster:
#                    ID  ...  interaccion_eventos_comida
# cluster               ...
# 0        5362.439560  ...                  693.340659
# 1        6651.666667  ...                 8277.333333
# 2        4361.526316  ...                 3341.263158
#
# [3 rows x 17 columns]
# Número de datos por cluster:
#  cluster
# 0    91
# 1     3
# 2    19
# Name: count, dtype: int64
# Iteración 1
# Media de ganancia de peso por sub_cluster:
# sub_cluster
# 0    0.257272
# 1    0.280004
# 2    0.345990
# Name: ganancia_peso, dtype: float64
# ...

# %%
# !python MLP_Algorithm_Code_09_23_09_29.py
# Out:
# Figure(1000x800)
# Mejores hiperparámetros: {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (64, 32, 16), 'learning_rate_init': 0.01}
# RMSE Test Redes Neuronales mejoradas: 0.137698679045674
# RMSE Train Redes Neuronales mejoradas: 0.095418681293188
# MSE Promedio de la validación cruzada: 0.010616675612940442
# Modelo guardado exitosamente.
# Figure(640x480)
# Figure(640x480)
# Media de variables desescaladas por cluster:
#                    ID  ...  interaccion_eventos_comida
# cluster               ...
# 0        5026.415254  ...                  477.110169
# 1        3541.833333  ...                 6174.333333
# 2        5291.000000  ...                 1657.720000
#
# [3 rows x 17 columns]
# Número de datos por cluster:
#  cluster
# 0    118
# 1      6
# 2     50
# Name: count, dtype: int64
# Iteración 1
# Media de ganancia de peso por sub_cluster:
# sub_cluster
# 0    0.348494
# 1    0.357775
# 2    0.324044
# Name: ganancia_peso, dtype: float64
# ...

# %%
# !python MLP_Algorithm_Code_09_30_10_6.py
# Out:
# Figure(1000x800)
# Mejores hiperparámetros: {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (100, 50, 25), 'learning_rate_init': 0.001}
# RMSE Test Redes Neuronales mejoradas: 0.1339135572321782
# RMSE Train Redes Neuronales mejoradas: 0.12867699187224374
# MSE Promedio de la validación cruzada: 0.0191442010381959
# Modelo guardado exitosamente.
# Figure(640x480)
# Figure(640x480)
# Media de variables desescaladas por cluster:
#                    ID  ...  interaccion_eventos_comida
# cluster               ...
# 0        5258.712418  ...                  708.261438
# 1        7432.666667  ...                 5081.166667
# 2        3901.628571  ...                 4415.771429
#
# [3 rows x 17 columns]
# Número de datos por cluster:
#  cluster
# 0    153
# 1     12
# 2     35
# Name: count, dtype: int64
# Iteración 1
# Media de ganancia de peso por sub_cluster:
# sub_cluster
# 0    0.378354
# 1    0.368659
# 2    0.455919
# Name: ganancia_peso, dtype: float64
# ...

# %%
# !python MLP_Algorithm_Code_10_7_10_13.py
# Out:
# Figure(1000x800)
# Mejores hiperparámetros: {'activation': 'tanh', 'alpha': 0.01, 'hidden_layer_sizes': (128, 64, 32), 'learning_rate_init': 0.01}
# RMSE Test Redes Neuronales mejoradas: 0.13316729775136632
# RMSE Train Redes Neuronales mejoradas: 0.10419263781452896
# MSE Promedio de la validación cruzada: 0.01291303969696293
# Modelo guardado exitosamente.
# Figure(640x480)
# Figure(640x480)
# Media de variables desescaladas por cluster:
#                    ID  ...  interaccion_eventos_comida
# cluster               ...
# 0        3993.857143  ...                 3531.190476
# 1        5311.611111  ...                  828.266667
# 2        1467.000000  ...                 7924.555556
#
# [3 rows x 17 columns]
# Número de datos por cluster:
#  cluster
# 0    21
# 1    90
# 2     9
# Name: count, dtype: int64
# Iteración 1
# Media de ganancia de peso por sub_cluster:
# sub_cluster
# 0    0.827972
# 1    0.651179
# 2    0.810050
# Name: ganancia_peso, dtype: float64
# ...

# %%
# !python MLP_Algorithm_Code_10_14_10_20.py
# Out:
# Figure(1000x800)
# Mejores hiperparámetros: {'activation': 'relu', 'alpha': 0.001, 'hidden_layer_sizes': (100, 50, 25), 'learning_rate_init': 0.01}
# RMSE Test Redes Neuronales mejoradas: 0.1917086432632624
# RMSE Train Redes Neuronales mejoradas: 0.08225279794050629
# MSE Promedio de la validación cruzada: 0.02468413888384289
# Modelo guardado exitosamente.
# Figure(640x480)
# Figure(640x480)
# Media de variables desescaladas por cluster:
#                    ID  ...  interaccion_eventos_comida
# cluster               ...
# 0        5307.913043  ...                  392.217391
# 1        5098.250000  ...                 4821.500000
# 2        3544.523810  ...                 1447.000000
#
# [3 rows x 17 columns]
# Número de datos por cluster:
#  cluster
# 0    69
# 1     4
# 2    21
# Name: count, dtype: int64
# Iteración 1
# Media de ganancia de peso por sub_cluster:
# sub_cluster
# 0    0.684004
# 1    0.825250
# 2    0.786303
# Name: ganancia_peso, dtype: float64
# ...

# %%
# !python MLP_Algorithm_Code_Total.py
# Out:
# Traceback (most recent call last):
#   File "c:\Users\alvar\Documents\Downloads\MLP_Algorithm_Code_Total.py", line 257, in <module>
#     main()
#   File "c:\Users\alvar\Documents\Downloads\MLP_Algorithm_Code_Total.py", line 4, in main
#     get_ipython().system('pip install psycopg2')
#     ^^^^^^^^^^^
# NameError: name 'get_ipython' is not defined

# %% [markdown]
# ## 3. Análisis de Clustering

# %%
# Ejecutar el script de clustering
# !python Clusters_study.py
# Out:
# Figure(1000x600)
# Figure(1000x600)
# Figure(1000x600)
# Figure(1000x600)
# Figure(1000x600)
# Figure(1000x600)
# Figure(1200x800)
# Figure(1000x600)
# Figure(1000x600)
# Figure(1000x600)
# Figure(1000x600)
# Figure(1000x600)
# Figure(1000x600)
# c:\Users\alvar\Documents\Downloads\Clusters_study.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   var_evolution_data['New_cluster'] = clustering.fit_predict(X)
# c:\Users\alvar\Documents\Downloads\Clusters_study.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# ## 4. Integración de Ensemble y Comparison

# %%
# Ejecutar los notebooks de Ensemble y Comparison
# !jupyter nbconvert --to notebook --execute path/to/ensemble_notebook.ipynb --output ensemble_executed.ipynb
# !jupyter nbconvert --to notebook --execute path/to/comparation_notebook.ipynb --output comparison_executed.ipynb
# Out:
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\alvar\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\Scripts\jupyter-nbconvert.EXE\__main__.py", line 4, in <module>
#   File "C:\Users\alvar\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\nbconvert\nbconvertapp.py", line 193, in <module>
#     class NbConvertApp(JupyterApp):
#   File "C:\Users\alvar\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\nbconvert\nbconvertapp.py", line 252, in NbConvertApp
#     Options include {get_export_names()}.
#                      ^^^^^^^^^^^^^^^^^^
# ...
